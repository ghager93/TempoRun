# %%
# %pylab
# %matplotlib inline

import scipy as sp

from sklearn.neighbors import KernelDensity
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
# %store -r data

# %%
peaks = np.where(data[2])[0]

# %%
kde = KernelDensity(bandwidth=1000).fit(peaks.reshape(-1, 1))

# %%
s = np.arange(100000)

# %%
e = kde.score_samples(s.reshape(-1, 1))

# %%
plt.plot(s, e)

# %%
sma = np.convolve(data[1], np.ones(1000)/1000, mode='valid')

# %%
plt.plot(sma)

# %%
def remove_gradients(arr):
    grad = arr[1:] - arr[:-1]
    mask = np.concatenate(([0], (grad[:-1] >= 0) & (grad[1:] <= 0), [0]))
    
    return np.where(mask, arr, 0)

# %%
def local_maxima(arr, n):
    for i in np.where(arr)[0]:
        print(i)

# %%
arr = data[1]
plt.plot(arr)

# %%
cnum = 0
peaks = np.where(arr)[0]
carr = np.array([peaks[i] for i in range(len(peaks)) if (peaks[i] == 0) or (i != 0 and (peaks[i]-peaks[i-1] > 1000))])

# %%
b = (carr[1:] - carr[:-1]).mean()
b
# Out:
# 11647.57142857143

# %%
22050 / b * 60
# Out:
# 113.58590999963204

# %%
xarr = np.convolve(arr, arr)
xarr.shape
# Out:
# (1,)
