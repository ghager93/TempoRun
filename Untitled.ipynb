# %%
# %pylab
# %matplotlib inline

import librosa
import scipy as sp
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
# %store -r song_data

# %%
def median_smoothing(arr, n):
    med_x = np.median(arr)
    x = np.concatenate((med_x*np.ones(n//2), arr, med_x*np.ones(n//2)))
    meds = np.array([np.median(x[t:t+n]) + sp.stats.median_abs_deviation(x[t:t+n]) for t in range(len(arr))])
    
    return np.where(arr > meds, arr, 0)

# %%
song, fs = song_data

# %%
dsong = sp.signal.decimate(song, 10)
ddsong = sp.signal.decimate(dsong, 10)

# %%
med = sp.ndimage.median_filter(dsong**2, fs//100)

# %%
plt.plot(med[100000:110000])

# %%
smo = median_smoothing(med, fs//100)

# %%
plt.plot(smo[10000:20000])

# %%
cnum = 0
peaks = np.where(smo)[0]
carr = np.array([peaks[i] for i in range(len(peaks)) if (peaks[i] == 0) or (i != 0 and (peaks[i]-peaks[i-1] > 100))])

# %%
b = (carr[1:] - carr[:-1]).mean()
fs / (10*b) * 60
# Out:
# 146.08109237597932
