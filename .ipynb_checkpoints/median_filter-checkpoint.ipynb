# %%
# %pylab
# %matplotlib inline

import scipy as sp
import librosa
import sounddevice
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
import importlib
importlib.reload(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ghage\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sounddevice.play(song, fs)

# %%
sounddevice.stop()

# %%
path = 'C://Users/ghage/Downloads/beat_detection_samples/bensound-jazzyfrenchy.mp3'

# %%
song, fs = librosa.load(path)
# Out:
# C:\Users\ghage\anaconda3\lib\site-packages\librosa\core\audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
wsong = sp.signal.wiener(song)
wsong.shape
# Out:
# (2309596,)

# %%
_, _, s = sp.signal.stft(song, fs, nperseg=int(0.03*fs), noverlap=int(0.01*fs))
s.shape
# Out:
# (331, 5239)

# %%
_, axs = plt.subplots(2, 1)
axs[0].pcolormesh(np.log(abs(s)))
axs[1].pcolormesh(np.log(abs(s))[:, 1000:1100])
# Out:
# <ipython-input-93-a270971256bb>:2: RuntimeWarning: divide by zero encountered in log
#   axs[0].pcolormesh(np.log(abs(s)))
# <ipython-input-93-a270971256bb>:3: RuntimeWarning: divide by zero encountered in log
#   axs[1].pcolormesh(np.log(abs(s))[:, 1000:1100])

# %%
h = sp.ndimage.median_filter(abs(s), (1, 10))
p = sp.ndimage.median_filter(abs(s), (6, 1))
h.shape, p.shape
# Out:
# ((331, 5239), (331, 5239))

# %%
_, axs = plt.subplots(2, 2)
axs[0, 0].pcolormesh(np.log(h))
axs[0, 1].pcolormesh(np.log(p))
axs[1, 0].pcolormesh(np.log(h)[:, 1000:1100])
axs[1, 1].pcolormesh(np.log(p)[:, 1000:1100])
# Out:
# <ipython-input-98-4027b96ad502>:3: RuntimeWarning: divide by zero encountered in log
#   axs[0, 1].pcolormesh(np.log(p))
# <ipython-input-98-4027b96ad502>:5: RuntimeWarning: divide by zero encountered in log
#   axs[1, 1].pcolormesh(np.log(p)[:, 1000:1100])

# %%
bin_mask = h / (h + p)

# %%
hm = np.where(bin_mask > 0.5, s, 10e-5)
pm = np.where(bin_mask < 0.5, s, 10e-5)

# %%
_, axs = plt.subplots(2, 2)
axs[0, 0].pcolormesh(np.log(abs(hm)))
axs[0, 1].pcolormesh(np.log(abs(pm)))
axs[1, 0].pcolormesh(np.log(abs(hm))[:, 1000:1100])
axs[1, 1].pcolormesh(np.log(abs(pm))[:, 1000:1100])
# Out:
# <ipython-input-101-ce35193f1141>:2: RuntimeWarning: divide by zero encountered in log
#   axs[0, 0].pcolormesh(np.log(abs(hm)))
# <ipython-input-101-ce35193f1141>:4: RuntimeWarning: divide by zero encountered in log
#   axs[1, 0].pcolormesh(np.log(abs(hm))[:, 1000:1100])

# %%
_, ih = sp.signal.istft(hm, fs, nperseg=int(0.03*fs), noverlap=int(0.01*fs))
_, ip = sp.signal.istft(pm, fs, nperseg=int(0.03*fs), noverlap=int(0.01*fs))

# %%
plt.plot(np.sum(abs(pm), axis=0)[1000:1200])

# %%
psum = np.sum(abs(pm), axis=0)

# %%
np.median(psum) + sp.stats.median_abs_deviation(psum)
# Out:
# 0.3309367597103119

# %%
med_x = np.median(psum)
n_t = 10
x = np.concatenate((med_x*np.ones(n_t//2), psum, med_x*np.ones(n_t//2)))
meds = np.array([np.median(x[t:t+n_t]) + sp.stats.median_abs_deviation(x[t:t+n_t]) for t in range(len(x)-n_t)])
meds.shape
# Out:
# (5239,)

# %%
plt.plot(psum)
plt.plot(meds)

# %%
plt.plot(smoothed[1000:1200], 'x')

# %%
smoothed = np.where(psum > meds, psum, 0)

# %%
m_forward = np.concatenate((smoothed[:-1] - smoothed[1:] > 0, [1]))
m_backward = np.concatenate(([1], smoothed[1:] - smoothed[:-1] > 0))
smoothed2 = np.where(m_forward & m_backward, smoothed, 0)

# %%
plt.plot(smoothed2[1000:2000])

# %%
peaks = np.where(smoothed2)[0]

# %%
_ = plt.hist(peaks[1:]-peaks[:-1], bins=np.arange(20))
_ = plt.xticks(np.arange(20))

# %%
_ = plt.hist(peaks[2:] - peaks[:-2], bins=np.arange(40))
_ = plt.xticks(np.arange(0, 40, 2), np.arange(0, 40, 2))

# %%
_ = plt.hist(peaks[3:] - peaks[:-3], bins=np.arange(60))
_ = plt.xticks(np.arange(0, 60, 3), np.arange(0, 60, 3))

# %%
beat_amp = 0.1*np.ones((1, s.shape[1]))
beat_amp[:, ::13] = 1

# %%
s_beat = beat_amp*s

# %%
plt.pcolormesh(abs(s_beat)[:, 1800:2000])

# %%
_, is_beat = sp.signal.istft(s_beat, fs, nperseg=int(0.03*fs), noverlap=int(0.01*fs))

# %%
60/.36
# Out:
# 166.66666666666669
