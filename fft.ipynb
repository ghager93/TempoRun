# %%
import numpy as np
import matplotlib.pyplot as plt
import sounddevice as sd
import pydub

from scipy import signal

# %%
l = 1024
f = 1 / 8
x = [np.cos(i * f * 2 * np.pi) for i in range(l)]

# %%
plt.plot(x)

# %%
fft_x = np.fft.fft(x)

# %%
plt.plot(abs(fft_x)[:l//2])
